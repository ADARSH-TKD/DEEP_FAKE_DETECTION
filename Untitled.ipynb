# %%
# ============================================================================
# SIMPLE CNN DEEPFAKE DETECTOR - JUPYTER NOTEBOOK VERSION
# Memory efficient with clear outputs for each cell
# ============================================================================

# %%
# CELL 1: Install Required Libraries (run once)
# ----------------------------------------------------------------------------
# !pip install tensorflow opencv-python numpy matplotlib scikit-learn pillow

# %%
# CELL 2: Import Libraries
# ----------------------------------------------------------------------------
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: []

# %%
# CELL 3: Configuration
# ----------------------------------------------------------------------------
# Your dataset path
DATASET_PATH = r'C:\Users\adarsh\OneDrive\Documents\GitHub\DEEP_FAKE_DETECTION\data_set'

# Training parameters
IMG_SIZE = (128, 128)  # Smaller size = faster training, less memory
BATCH_SIZE = 32        # Reduce to 16 or 8 if memory issues
EPOCHS = 15            # Number of training cycles
LEARNING_RATE = 0.001

print("Configuration:")
print(f"  Dataset: {DATASET_PATH}")
print(f"  Image Size: {IMG_SIZE}")
print(f"  Batch Size: {BATCH_SIZE}")
print(f"  Epochs: {EPOCHS}")
# Out:
# Configuration:
#   Dataset: C:\Users\adarsh\OneDrive\Documents\GitHub\DEEP_FAKE_DETECTION\data_set
#   Image Size: (128, 128)
#   Batch Size: 32
#   Epochs: 15

# %%
# CELL 4: Create Data Generators (Memory Efficient!)
# ----------------------------------------------------------------------------
print("Creating data generators...")

# Training data with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    fill_mode='nearest'
)

# Validation and test data (no augmentation)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_generator = train_datagen.flow_from_directory(
    os.path.join(DATASET_PATH, 'Train'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    classes=['Real', 'Fake'],
    shuffle=True
)

validation_generator = val_test_datagen.flow_from_directory(
    os.path.join(DATASET_PATH, 'Validation'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    classes=['Real', 'Fake'],
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    os.path.join(DATASET_PATH, 'Test'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    classes=['Real', 'Fake'],
    shuffle=False
)

print("\n✓ Data generators created!")
print(f"Training samples: {train_generator.samples}")
print(f"Validation samples: {validation_generator.samples}")
print(f"Test samples: {test_generator.samples}")
print(f"Class mapping: {train_generator.class_indices}")
# Out:
# Creating data generators...
# Found 801 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
#
# ✓ Data generators created!
# Training samples: 801
# Validation samples: 800
# Test samples: 800
# Class mapping: {'Real': 0, 'Fake': 1}

# %%
# CELL 5: Visualize Sample Images (Optional but Recommended!)
# ----------------------------------------------------------------------------
print("Sample images from training set:")

# Get a batch of images
sample_batch = next(train_generator)
sample_images = sample_batch[0]
sample_labels = sample_batch[1]

# Plot 8 random images
plt.figure(figsize=(15, 8))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(sample_images[i])
    label = 'FAKE' if sample_labels[i] == 1 else 'REAL'
    plt.title(f'{label}', fontsize=12, fontweight='bold')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Sample images from training set:

# %%
# CELL 6: Build Simple CNN Model
# ----------------------------------------------------------------------------
print("Building Simple CNN Model...")

model = models.Sequential([
    # Block 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(*IMG_SIZE, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Block 2
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Block 3
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Block 4
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Dense Layers
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    
    # Output
    layers.Dense(1, activation='sigmoid')
])

print("\n✓ Model created!")
print(f"Total parameters: {model.count_params():,}")
model.summary()
# Out:
# Building Simple CNN Model...
# C:\Users\adarsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ✓ Model created!
# Total parameters: 5,177,281
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# CELL 7: Compile Model
# ----------------------------------------------------------------------------
print("Compiling model...")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall'),
        keras.metrics.AUC(name='auc')
    ]
)

print("✓ Model compiled!")
# Out:
# Compiling model...
# ✓ Model compiled!

# %%
# CELL 8: Setup Callbacks
# ----------------------------------------------------------------------------
callbacks = [
    # Save best model
    keras.callbacks.ModelCheckpoint(
        'best_deepfake_cnn.h5',
        save_best_only=True,
        monitor='val_accuracy',
        mode='max',
        verbose=1
    ),
    
    # Reduce learning rate on plateau
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),
    
    # Early stopping
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    )
]

print("✓ Callbacks configured!")
# Out:
# ✓ Callbacks configured!

# %%
# CELL 9: Train Model (This will take time!)
# ----------------------------------------------------------------------------
print("\n" + "="*60)
print("STARTING TRAINING")
print("="*60)

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print("\n" + "="*60)
print("TRAINING COMPLETE!")
print("="*60)
# Out:
# ...
# STARTING TRAINING
# ...
# C:\Users\adarsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.6703 - auc: 0.7355 - loss: 0.7706 - precision: 0.6855 - recall: 0.6208
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to best_deepfake_cnn.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
# CELL 10: Plot Training History
# ----------------------------------------------------------------------------
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Accuracy
axes[0, 0].plot(history.history['accuracy'], 'b-', label='Training', linewidth=2)
axes[0, 0].plot(history.history['val_accuracy'], 'r-', label='Validation', linewidth=2)
axes[0, 0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Epoch', fontsize=12)
axes[0, 0].set_ylabel('Accuracy', fontsize=12)
axes[0, 0].legend(fontsize=10)
axes[0, 0].grid(True, alpha=0.3)

# Loss
axes[0, 1].plot(history.history['loss'], 'b-', label='Training', linewidth=2)
axes[0, 1].plot(history.history['val_loss'], 'r-', label='Validation', linewidth=2)
axes[0, 1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Epoch', fontsize=12)
axes[0, 1].set_ylabel('Loss', fontsize=12)
axes[0, 1].legend(fontsize=10)
axes[0, 1].grid(True, alpha=0.3)

# Precision
axes[1, 0].plot(history.history['precision'], 'b-', label='Training', linewidth=2)
axes[1, 0].plot(history.history['val_precision'], 'r-', label='Validation', linewidth=2)
axes[1, 0].set_title('Model Precision', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Epoch', fontsize=12)
axes[1, 0].set_ylabel('Precision', fontsize=12)
axes[1, 0].legend(fontsize=10)
axes[1, 0].grid(True, alpha=0.3)

# Recall
axes[1, 1].plot(history.history['recall'], 'b-', label='Training', linewidth=2)
axes[1, 1].plot(history.history['val_recall'], 'r-', label='Validation', linewidth=2)
axes[1, 1].set_title('Model Recall', fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('Epoch', fontsize=12)
axes[1, 1].set_ylabel('Recall', fontsize=12)
axes[1, 1].legend(fontsize=10)
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_results.png', dpi=300, bbox_inches='tight')
print("✓ Training plots saved as 'training_results.png'")
plt.show()
# Out:
# ✓ Training plots saved as 'training_results.png'

# %%
test_results = model.evaluate(test_generator, verbose=1)

print("\n" + "="*60)
print("TEST RESULTS")
print("="*60)
print(f"Loss:      {test_results[0]:.4f}")
print(f"Accuracy:  {test_results[1]:.4f} ({test_results[1]*100:.2f}%)")
print(f"Precision: {test_results[2]:.4f}")
print(f"Recall:    {test_results[3]:.4f}")
print(f"AUC:       {test_results[4]:.4f}")
print("="*60)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.2919 - auc: 0.3891 - loss: 0.8305 - precision: 0.1895 - recall: 0.5186
#
# ...
# TEST RESULTS
# ...
# Loss:      0.6721
# Accuracy:  0.5537 (55.37%)
# Precision: 0.5297
# Recall:    0.9600
# AUC:       0.7136
# ...

# %%
# CELL 12: Create Prediction Function
# ----------------------------------------------------------------------------
def predict_image(image_path, threshold=0.5):
    """
    Predict if an image is REAL or FAKE
    """
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        return "Error: Could not load image", 0.0
    
    # Preprocess
    img = cv2.resize(img, IMG_SIZE)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0
    img = np.expand_dims(img, axis=0)
    
    # Predict
    prediction = model.predict(img, verbose=0)[0][0]
    
    if prediction >= threshold:
        label = 'FAKE'
        confidence = prediction * 100
    else:
        label = 'REAL'
        confidence = (1 - prediction) * 100
    
    return label, confidence

def visualize_prediction(image_path):
    """
    Visualize image with prediction
    """
    label, confidence = predict_image(image_path)
    
    # Load and display image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(img)
    
    # Color based on prediction
    color = 'red' if label == 'FAKE' else 'green'
    plt.title(f'Prediction: {label}\nConfidence: {confidence:.2f}%', 
              fontsize=16, fontweight='bold', color=color)
    plt.axis('off')
    plt.tight_layout()
    plt.show()
    
    return label, confidence

print("✓ Prediction functions created!")
# Out:
# ✓ Prediction functions created!

# %%
# CELL 13: Test Predictions (Example Usage)
# ----------------------------------------------------------------------------
# Example: Predict on a single image
# Replace 'path/to/your/image.jpg' with actual image path

"""
# Uncomment to use:

# Simple prediction
label, confidence = predict_image('path/to/your/image.jpg')
print(f"Prediction: {label}")
print(f"Confidence: {confidence:.2f}%")

# Visual prediction
visualize_prediction('path/to/your/image.jpg')
"""
# Out:
# '\n# Uncomment to use:\n\n# Simple prediction\nlabel, confidence = predict_image(\'path/to/your/image.jpg\')\nprint(f"Prediction: {label}")\nprint(f"Confidence: {confidence:.2f}%")\n\n# Visual prediction\nvisualize_prediction(\'path/to/your/image.jpg\')\n'

# %%
# CELL 14: Batch Prediction on Test Set
# ----------------------------------------------------------------------------
def predict_test_samples(num_samples=10):
    """
    Predict on random test samples and visualize
    """
    # Reset test generator
    test_generator.reset()
    
    # Get a batch
    batch = next(test_generator)
    images = batch[0]
    true_labels = batch[1]
    
    # Predict
    predictions = model.predict(images[:num_samples], verbose=0)
    
    # Visualize
    plt.figure(figsize=(20, 8))
    for i in range(min(num_samples, len(images))):
        plt.subplot(2, 5, i+1)
        plt.imshow(images[i])
        
        pred_label = 'FAKE' if predictions[i][0] >= 0.5 else 'REAL'
        true_label = 'FAKE' if true_labels[i] == 1 else 'REAL'
        confidence = predictions[i][0] * 100 if predictions[i][0] >= 0.5 else (1 - predictions[i][0]) * 100
        
        # Color: green if correct, red if wrong
        color = 'green' if pred_label == true_label else 'red'
        
        plt.title(f'Pred: {pred_label} ({confidence:.1f}%)\nTrue: {true_label}',
                  fontsize=10, fontweight='bold', color=color)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Run prediction on 10 random test samples
predict_test_samples(10)

# %%
# CELL 15: Save Model (Final Step)
# ----------------------------------------------------------------------------
# Save the final model
model.save('final_deepfake_cnn.h5')
print("✓ Model saved as 'final_deepfake_cnn.h5'")

# Also save as SavedModel format (recommended for deployment)
model.save('deepfake_cnn_model', save_format='tf')
print("✓ Model saved as 'deepfake_cnn_model/' (TensorFlow format)")

print("\n" + "="*60)
print("ALL DONE! 🎉")
print("="*60)
print("\nYour trained model is ready to use!")
print("Model files:")
print("  - best_deepfake_cnn.h5 (best model during training)")
print("  - final_deepfake_cnn.h5 (final model)")
print("  - training_results.png (training plots)")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Model saved as 'final_deepfake_cnn.h5'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5 print("✓ Model saved as 'final_deepfake_cnn.h5'")
#       7 # Also save as SavedModel format (recommended for deployment)
# ----> 8 model.save('deepfake_cnn_model', save_format='tf')
#       9 print("✓ Model saved as 'deepfake_cnn_model/' (TensorFlow format)")
#      11 print("\n" + "="*60)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...
